# %% [markdown]
# <a href="https://colab.research.google.com/github/hiamitabha/course/blob/master/notebooks/Fine_Tuning_Llama_13B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Finetune Llama-2-13b on a Google colab
#
# Based of the colab notebook available in the tutorial available at: https://youtu.be/eeM6V5aPjhk
#
# Welcome to this Google Colab notebook that shows how to fine-tune the recent Llama-2-7b model on a single Google colab and turn it into a chatbot for the Petoi Bittle robot.
#
# We will leverage PEFT library from Hugging Face ecosystem, as well as QLoRA for more memory efficient finetuning

# %% [markdown]
# ## Setup
#
# Run the cells below to setup and install the required libraries. For our experiment we will need `accelerate`, `peft`, `transformers`, `datasets` and TRL to leverage the recent [`SFTTrainer`](https://huggingface.co/docs/trl/main/en/sft_trainer). We will use `bitsandbytes` to [quantize the base model into 4bit](https://huggingface.co/blog/4bit-transformers-bitsandbytes). We will also install `einops` as it is a requirement to load Falcon models.

# %%
# !pip install -q -U trl transformers accelerate git+https://github.com/huggingface/peft.git
# !pip install -q datasets bitsandbytes einops wandb
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 49.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 20.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.2/492.2 kB 31.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 19.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 97.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 80.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 27.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.9 MB/s eta 0:00:00
#   Building wheel for peft (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 39.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 20.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.7/214.7 kB 18.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.8 MB/s eta 0:00:00
#   Building wheel for pathtools (setup.py) ... done

# %% [markdown]
# ## Dataset

# %%
from datasets import load_dataset

dataset_name = 'hiamitabha/bittle' #dataset for fine tuning the Petoi Bittle
dataset = load_dataset(dataset_name, split="train")
# Out:
# Downloading readme:   0%|          | 0.00/91.0 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/6.40k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/950 [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# We use the Llama2 model in the step below. Prior to using Llama2, the license reeuires you to sign up at the Meta website and accept their agreement form to use Llama2.

# %% [markdown]
# ## Loading the model

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, AutoTokenizer

model_name = "meta-llama/Llama-2-13b-chat-hf"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    trust_remote_code=True
)
model.config.use_cache = False
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# Downloading (…)fetensors.index.json:   0%|          | 0.00/33.4k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading (…)of-00003.safetensors:   0%|          | 0.00/9.95G [00:00<?, ?B/s]
# Downloading (…)of-00003.safetensors:   0%|          | 0.00/9.90G [00:00<?, ?B/s]
# Downloading (…)of-00003.safetensors:   0%|          | 0.00/6.18G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/167 [00:00<?, ?B/s]

# %% [markdown]
# Let's also load the tokenizer below

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/749 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
from peft import LoraConfig, get_peft_model

lora_alpha = 16
lora_dropout = 0.1
lora_r = 64

peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM"
)

# %% [markdown]
# ## Loading the trainer

# %% [markdown]
# Here we will use the [`SFTTrainer` from TRL library](https://huggingface.co/docs/trl/main/en/sft_trainer) that gives a wrapper around transformers `Trainer` to easily fine-tune models on instruction based datasets using PEFT adapters. Let's first load the training arguments below.

# %%
from transformers import TrainingArguments

output_dir = "./results"
per_device_train_batch_size = 4
gradient_accumulation_steps = 4
optim = "paged_adamw_32bit"
save_steps = 100
logging_steps = 10
learning_rate = 2e-4
max_grad_norm = 0.3
max_steps = 100
warmup_ratio = 0.03
lr_scheduler_type = "constant"

training_arguments = TrainingArguments(
    output_dir=output_dir,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    fp16=True,
    max_grad_norm=max_grad_norm,
    max_steps=max_steps,
    warmup_ratio=warmup_ratio,
    group_by_length=True,
    lr_scheduler_type=lr_scheduler_type,
)

# %% [markdown]
# Then finally pass everthing to the trainer

# %%
from trl import SFTTrainer

max_seq_length = 512

trainer = SFTTrainer(
    model=model,
    train_dataset=dataset,
    peft_config=peft_config,
    dataset_text_field="text",
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_arguments,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:102: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]

# %% [markdown]
# We will also pre-process the model by upcasting the layer norms in float 32 for more stable training

# %%
for name, module in trainer.model.named_modules():
    if "norm" in name:
        module = module.to(torch.float32)

# %% [markdown]
# ## Train the model

# %% [markdown]
# Now let's train the model! Simply call `trainer.train()`

# %%
trainer.train()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.15.7
# Run data is saved locally in <code>/content/wandb/run-20230727_062902-g1krg4b8</code>
# Syncing run <strong><a href='https://wandb.ai/learnwitharobot/huggingface/runs/g1krg4b8' target="_blank">earnest-bee-1</a></strong> to <a href='https://wandb.ai/learnwitharobot/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/learnwitharobot/huggingface' target="_blank">https://wandb.ai/learnwitharobot/huggingface</a>
#  View run at <a href='https://wandb.ai/learnwitharobot/huggingface/runs/g1krg4b8' target="_blank">https://wandb.ai/learnwitharobot/huggingface/runs/g1krg4b8</a>
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 03:59, Epoch 100/100]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>0.666700</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.169500</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.060500</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.056600</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.047900</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.023900</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.000500</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=100, training_loss=0.1025778804536094, metrics={'train_runtime': 336.0672, 'train_samples_per_second': 4.761, 'train_steps_per_second': 0.298, 'total_flos': 149580957696000.0, 'train_loss': 0.1025778804536094, 'epoch': 100.0})

# %%
model_to_save = trainer.model.module if hasattr(trainer.model, 'module') else trainer.model  # Take care of distributed/parallel training
model_to_save.save_pretrained("outputs")

# %%
lora_config = LoraConfig.from_pretrained('outputs')
model = get_peft_model(model, lora_config)

# %%
text = "###Human: Give me some good reasons to buy the Petoi Bittle robot. ### Assistant: "
device = "cuda:0"

inputs = tokenizer(text, return_tensors="pt").to(device)
outputs = model.generate(**inputs, max_new_tokens=256)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# ###Human: Give me some good reasons to buy the Petoi Bittle robot. ### Assistant: 1. Advanced AI Technology: The Petoi Bittle robot is equipped with advanced AI technology that allows it to learn and adapt to its environment, making it a highly intelligent and interactive companion. 2. Customizable: The Bittle robot can be customized with different skins and accessories, allowing you to personalize your robot and make it unique to your preferences. 3. Long Battery Life: The Bittle robot has a long battery life, allowing you to enjoy hours of fun and entertainment without needing to recharge. 4. Voice Control: The Bittle robot can be controlled using voice commands, making it easy and convenient to use. 5. Educational: The Bittle robot can be used as an educational tool to teach children about programming, robotics, and AI technology. 6. Affordable: The Bittle robot is an affordable option compared to other robots on the market, making it a great value for the price. 7. Compatible with Other Devices: The Bittle robot can be controlled using a smartphone app, allowing you to control it from anywhere in the world. 8. Fun and Interactive: The Bittle robot is

# %%
model.push_to_hub("hiamitabha/llama2forbittlerobot")
# Out:
# CommitInfo(commit_url='https://huggingface.co/hiamitabha/llama2forbittlerobot/commit/cefef8d2e75f9d8149e731443c0b966e4f1b7bb4', commit_message='Upload model', commit_description='', oid='cefef8d2e75f9d8149e731443c0b966e4f1b7bb4', pr_url=None, pr_revision=None, pr_num=None)
